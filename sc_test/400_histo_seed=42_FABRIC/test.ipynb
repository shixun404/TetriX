# %%
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import torch as th
with open('diameter_list_400_3_DGRO_epsilon_greedy_eps=0.99_startnode.pkl', 'rb') as f:
    data_DGRO_heuristic = pkl.load(f)
import ast

# # Read and parse a Python list from file
with open("RL_1.txt", "r") as f:
    data_RL = ast.literal_eval(f.read())
print(data_RL)
print(data_DGRO_heuristic)
print(len(data_RL), len(data_DGRO_heuristic))
weights1 = th.ones(len(data_RL)) / len(data_RL)
weights2 = th.ones(len(data_DGRO_heuristic)) / len(data_DGRO_heuristic)
plt.figure()
plt.hist(data_RL, bins=50, alpha=0.8, label='DGRO-DQN', weights=weights1)
plt.hist(data_DGRO_heuristic, bins=50, alpha=0.8, label='DGRO-Greedy', weights=weights2)
# plt.show()
# plt.axvline(x=315, color='red', linestyle='--', linewidth=2, label='Chord')
# plt.axvline(x=239, color='green', linestyle='--', linewidth=2, label='Nearest Neighbour')
# plt.axvline(x=505, color='black', linestyle='--', linewidth=2, label='Rapid')
plt.title(' DGRO Training Performance: Diameter Distribution RL N=400 K=3')
plt.legend()
plt.savefig('DGRO_training_performance_diameter_distribution_N=400_K=3.pdf')
# with open
# Out:
# [1441, 1263, 1423, 1491, 1543, 1399, 1391, 1572, 1377, 1485, 1579, 1528, 1379, 1580, 1363, 1520, 1447, 1402, 1357, 1459, 1302, 1598, 1375, 1632, 1356, 1573, 1298, 1340, 1366, 1430, 1371, 1575, 1420, 1582, 1434, 1406, 1570, 1461, 1559, 1420, 1443, 1570, 1336, 1380, 1373, 1518, 1634, 1519, 1404, 1723, 1511, 1454, 1421, 1237, 1333, 1425, 1361, 1427, 1554, 1460, 1843, 1420, 1330, 1592, 1482, 1366, 1514, 1348, 1348, 1454, 1383, 1411, 1601, 1271, 1423, 1412, 1489, 1512, 1427, 1502, 1466, 1450, 1353, 1304, 1468, 1325, 1308, 1706, 1427, 1433, 1329, 1768, 1418, 1642, 1315, 1415, 1510, 1340, 1559, 1470, 1414, 1306, 1520, 1613, 1399, 1367, 1412, 1386, 1385, 1404, 1547, 1364, 1409, 1621, 1357, 1380, 1450, 1543, 1473, 1316, 1458, 1360, 1553, 1541, 1641, 1553, 1537, 1318, 1297, 1527, 1460, 1458, 1515, 1370, 1555, 1464, 1276, 1378, 1387, 1731, 1370, 1370, 1420, 1504, 1497, 1357, 1411, 1505, 1403, 1559, 1641, 1519, 1430, 1589, 1516, 1402, 1456, 1377, 1477, 1438, 1472, 1544, 1429, 1429, 1360, 1423, 1715, 1564, 1459, 1302, 1451, 1361, 1615, 1366, 1556, 1336, 1216, 1453, 1481, 1376, 1441, 1370, 1358, 1514, 1342, 1421, 1438, 1741, 1256, 1393, 1523, 1373, 1453, 1313, 1156, 1407, 1337, 1493, 1465, 1342, 1424, 1379, 1409, 1389, 1387, 1289, 1353, 1334, 1284, 1359, 1502, 1359, 1422, 1452, 1358, 1413, 1353, 1419, 1471, 1457, 1495, 1515, 1376, 1400, 1524, 1360, 1536, 1618, 1308, 1334, 1397, 1589, 1551, 1403, 1490, 1419, 1443, 1512, 1592, 1463, 1351, 1483, 
1468, 1494, 1632, 1450, 1666, 1371, 1733, 1500, 1532, 1437, 1789, 1677, 1516, 1647, 1536, 1514, 1457, 1483, 1537, 1432, 1613, 1522, 1666, 1610, 1538, 1447, 1696, 1499, 1601, 1481, 1425, 1590, 1661, 1626, 1589, 1600, 1607, 1426, 1531, 1656, 1601, 1553, 1602, 1668, 1610, 1486, 1584, 1458, 1486, 1824, 1826, 1627, 1551, 1962, 1593, 1481, 1587, 1488, 1714, 1678, 1608, 1561, 1682, 1519, 1525, 1553, 1439, 1479, 1639, 1570, 1541, 1538, 1384, 1626, 1735, 1594, 1446, 1685, 1609, 1755, 1704, 1545, 1511, 1416, 1517, 1710, 1601, 1616, 1567, 1563, 1581, 1293, 1556, 1489, 1559, 1407, 1655, 1650, 1481, 1461, 1516, 1496, 1606, 1620, 1566, 1618, 1558, 1543, 1472, 1651, 1593, 1603, 1672, 1416, 1677, 1445, 1498, 1596, 1495, 1599, 1392, 1483, 1543, 1662, 1533, 1568, 1491, 1545, 1828, 1441, 1894, 1657, 1757, 1589, 1534, 1571, 1713, 1648, 1661, 1521, 1652, 1327, 1691, 1708, 1938, 1679, 1673, 1501, 1738, 1515, 1389, 1607, 1695, 1407, 1604, 1683, 1579, 1463, 1574, 1620, 1668, 1561, 1478, 1542, 1545, 1449, 1618, 1345, 1601, 1418, 1618, 1534, 1549, 1426, 1520, 1605, 1477, 1459, 1642, 1593, 1383, 1695, 1772, 1574, 1381, 1792, 1546, 1651, 1422, 1748, 1491, 1733, 1693, 1496, 2035, 1553, 1447, 1665, 1497, 1451, 1556, 1531, 1694, 1439, 1426, 1612, 1526, 1495, 1450, 1613, 1640, 1572, 1459, 1571, 1575, 1534, 1445, 1573, 1377, 1425, 1511, 1437, 1517, 1635, 1611, 1709, 1470, 1591, 1535, 1644, 1587, 1501, 1632, 1410, 1557, 1719, 1588, 1427, 1556, 1451, 1634, 1480, 1490, 1490, 1559, 1404, 1512, 1561, 1696, 1907, 1609, 155 ...
# 601 3000

# %%
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import torch as th
data_DGRO_heuristic = []
with open('/pscratch/sd/s/swu264/TetriX/sc_test/100_histo_seed=42/diameter_list_100_3_DGRO_epsilon_greedy_eps=0.99.pkl', 'rb') as f:
    data_DGRO_heuristic.append(pkl.load(f))
with open('/pscratch/sd/s/swu264/TetriX/sc_test/100_histo_seed=42/diameter_list_100_4_DGRO_epsilon_greedy_eps=0.99_startnode.pkl', 'rb') as f:
    data_DGRO_heuristic.append(pkl.load(f))
with open('/pscratch/sd/s/swu264/TetriX/sc_test/100_histo_seed=42/diameter_list_100_5_DGRO_epsilon_greedy_eps=0.99_startnode.pkl', 'rb') as f:
    data_DGRO_heuristic.append(pkl.load(f))
with open('/pscratch/sd/s/swu264/TetriX/sc_test/100_histo_seed=42/diameter_list_100_6_DGRO_epsilon_greedy_eps=0.99_startnode.pkl', 'rb') as f:
    data_DGRO_heuristic.append(pkl.load(f))
import ast
with open("/pscratch/sd/s/swu264/TetriX/sc_test/100_histo_seed=42/RL_1.txt", "r") as f:
    data_RL = ast.literal_eval(f.read())


alpha = 0.7
plt.figure()




plt.hist(data_DGRO_heuristic[3], bins=50, alpha=alpha, label='DGRO-Greedy K=6')
plt.hist(data_DGRO_heuristic[2], bins=50, alpha=alpha, label='DGRO-Greedy K=5')
plt.hist(data_DGRO_heuristic[1], bins=50, alpha=alpha, label='DGRO-Greedy K=4')
plt.hist(data_RL, bins=50, alpha=0.8, label='DGRO-DQN K=3')
plt.hist(data_DGRO_heuristic[0], bins=50, alpha=alpha, label='DGRO-Greedy K=3')
plt.axvline(x=315, color='red', linestyle='--', linewidth=2, label='Chord')
plt.axvline(x=239, color='green', linestyle='--', linewidth=2, label='Nearest Neighbour')
plt.axvline(x=505, color='black', linestyle='--', linewidth=2, label='Rapid')
plt.xlabel('Diameter')
plt.ylabel('Frenquency')
plt.title(' DGRO Training Performance: Diameter Distribution RL N=100 K=3')
plt.legend()
plt.savefig('DGRO_training_performance_diameter_distribution_N=100_K=345.pdf')
# with open

# %%
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import torch as th
with open('/pscratch/sd/s/swu264/TetriX/sc_test/histo_seed=10086/diameter_list_100_3_DGRO_epsilon_greedy_eps=0.99.pkl', 'rb') as f:
    data_DGRO_heuristic = pkl.load(f)
import ast

# Read and parse a Python list from file
with open("/pscratch/sd/s/swu264/TetriX/sc_test/histo_seed=10086/RL_1.txt", "r") as f:
    data_RL = ast.literal_eval(f.read())

print(len(data_RL), len(data_DGRO_heuristic))
plt.figure()
plt.hist(data_RL, bins=50, alpha=0.8, label='DGRO-DQN')
plt.hist(data_DGRO_heuristic, bins=50, alpha=0.8, label='DGRO-Greedy')
plt.axvline(x=339, color='red', linestyle='--', linewidth=2, label='Chord')
plt.axvline(x=221, color='green', linestyle='--', linewidth=2, label='Nearest Neighbour')
plt.axvline(x=517, color='black', linestyle='--', linewidth=2, label='Rapid')
plt.title('DGRO Generalization on Different Graph: Diameter Distribution RL N=100 K=3')
plt.legend()
plt.tight_layout()
plt.savefig('DGRO_generalization_performance_diameter_distribution_N=100_K=3.pdf', bbox_inches='tight')
# Out:
# 3000 2501

# %%
import networkx as nx
import json
import pickle as pkl

# Load the node mapping (IP:PORT → idx)
# with open('100_best_graph.pkl', 'rb') as f:
with open('../FABRIC_400_best_test_graph.pkl', 'rb') as f:
    graph = pkl.load(f)
# with open("../node_mapping_100.pkl", "rb") as f:
with open("../node_mapping_400.pkl", "rb") as f:
    node_mapping = pkl.load(f)

# Invert the mapping to get (idx → IP:PORT)
idx_to_ip = {idx: ip_port for ip_port, idx in node_mapping.items()}


# Prepare the outgoing connections mapping
outgoing_connections = {}

for node in graph.nodes():
    if node in idx_to_ip:
        node_ip = idx_to_ip[node]  # Convert idx back to IP:PORT
        neighbors = list(graph.successors(node))  # Outgoing neighbors
        # Convert neighbor indices back to IP:PORT
        neighbor_ips = [idx_to_ip[neighbor] for neighbor in neighbors if neighbor in idx_to_ip]
        # Store the outgoing connections
        outgoing_connections[node_ip] = neighbor_ips

# Save as JSON file
with open("outgoing_connections.json", "w") as f:
    json.dump(outgoing_connections, f, indent=4)
