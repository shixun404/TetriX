 939.0, 909.0, 859.0], 'K_ring_shortest_ring': [2451.0, 1654.0, 1418.0, 1301.0, 1242.0, 1292.0, 1113.0, 1099.0], 'K_ring_random_ring': [4589.0, 2435.0, 1841.0, 1718.0, 1518.0, 1369.0, 1284.0, 1237.0], 'K_ring_greedy': [2626.0, 1278.0, 1064.0, 1019.0, 913.0, 890.0, 780.0, 755.0], 'K_ring_epsilon_greedy': [2173.0, 1262.0, 968.0, 862.0, 875.0, 846.0, 725.0, 788.0], 'K_ring_random_distributed_stride_1': [4201.0, 2362.0, 1784.0, 1587.0, 1473.0, 1360.0, 1332.0, 1224.0], 'K_ring_random_distributed_stride_2': [4612.0, 2305.0, 1797.0, 1569.0, 1468.0, 1315.0, 1310.0, 1239.0], 'K_ring_random_distributed_stride_4': [4272.0, 2128.0, 1684.0, 1492.0, 1382.0, 1273.0, 1195.0, 1190.0], 'K_ring_random_distributed_stride_8': [3610.0, 1920.0, 1562.0, 1369.0, 1319.0, 1197.0, 1213.0, 1125.0], 'K_ring_random_distributed_stride_16': [3376.0, 1762.0, 1439.0, 1311.0, 1190.0, 1110.0, 932.0, 1056.0], 'K_ring_random_distributed_stride_32': [3446.0, 1739.0, 1242.0, 1119.0, 946.0, 859.0, 878.0, 851.0], 'K_ring_random_distributed_stride_64': [2633.0, 1356.0, 1197.0, 973.0, 998.0, 841.0, 862.0, 893.0], 'K_ring_random_distributed_stride_128': [2286.0, 1208.0, 1107.0, 946.0, 920.0, 873.0, 871.0, 783.0], 'K_ring_random_distributed_stride_256': [2276.0, 1309.0, 1106.0, 917.0, 982.0, 992.0, 878.0, 822.0], 'K_ring_random_distributed_stride_512': [4944.0, 2052.0, 1693.0, 1607.0, 1471.0, 1664.0, 1583.0, 1450.0]}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
color = sns.color_palette(n_colors=4)
i = 0
# id = [0, 1, 3, 7]
id = [0, 1, 2, 3, 4, 5, 6, 7]
color_id = [0, 0, 2, 1, 1,  3, 3, 3]
degree = np.array(degree)
linestyle = ['-', '--', '-',  '-', '--', '-', '--', '-']
for key, value in diameter.items():
    if key != 'DGRO-DQN':
        plt.plot(degree[id], np.array(value)[id], label=key, color=color[color_id[i]], linestyle=linestyle[i])
        i += 1
plt.plot(degree[[0, 1, 3]], np.array(diameter['DGRO-DQN']), label='DGRO-DQN', linestyle=linestyle[i], color = color[-1])
plt.xlabel('degree')
# plt.ylim([700, 4000])
# plt.ylim([700, 2000])
plt.ylabel('diameter')
plt.yscale('log', base=10)
# plt.xscale('log', base=2)
plt.title('Diameter vs Degree')
plt.legend()
plt.grid()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
color = sns.color_palette(n_colors=4)
i = 0
# id = [0, 1, 3, 7]
id = [0, 1, 2, 3, 4, 5, 6, 7]
color_id = [0, 0, 2, 1, 1, 3, 3, 3]
degree = np.array(degree)
linestyle = ['-', '--', '-', '-', '--',  '-', '--', '-']
for key, value in diameter.items():
    if key != 'DGRO-DQN':
        plt.plot(degree[id], np.array(value)[id], label=key, color=color[color_id[i]], linestyle=linestyle[i])
        i += 1
plt.plot(degree[[0, 1, 3]], np.array(diameter['DGRO-DQN']), label='DGRO-DQN', linestyle=linestyle[i], color = color[-1])
plt.xlabel('degree')
# plt.ylim([700, 4000])
plt.ylim([700, 2000])
plt.ylabel('diameter')
# plt.yscale('log', base=10)
# plt.xscale('log', base=2)
plt.title('Diameter vs Degree')
plt.legend()
plt.grid()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib import rcParams
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# 数据准备（你要确保 degree 和 diameter 已经定义）
color = sns.color_palette(n_colors=4)
id = [0, 1, 2, 3, 4, 5, 6, 7]
color_id = [0, 0, 2, 1, 1,  3, 3, 3]
linestyle = ['-', '--', '-', '-', '--',  '-', '--', '-']
degree = np.array(degree)

# 创建主图和嵌套图
fig, ax = plt.subplots(figsize=(7, 7))
axins = inset_axes(ax, width="35%", height="35%", loc='upper right')

# 主图：放大视图
i = 0
for key, value in diameter.items():
    if key != 'DGRO-DQN':
        ax.plot(degree[id], np.array(value)[id], label=key,
                color=color[color_id[i]], linestyle=linestyle[i])
        i += 1
ax.plot(degree[[0, 1, 3]], np.array(diameter['DGRO-DQN']),
        label='DGRO-DQN', linestyle=linestyle[i], color=color[-1])

ax.set_xlabel('Degree', fontsize=14)
ax.set_ylabel('Diameter', fontsize=14)
ax.set_ylim([600, 2500])
ax.set_title('Diameter vs Degree')
ax.legend(fontsize=12, loc='lower left', ncols=3)
ax.grid(True)

# 嵌套图：完整视图，log y-scale
i = 0
for key, value in diameter.items():
    if key != 'DGRO-DQN':
        axins.plot(degree[id], np.array(value)[id], 
                   color=color[color_id[i]], linestyle=linestyle[i])
        i += 1
axins.plot(degree[[0, 1, 3]], np.array(diameter['DGRO-DQN']), 
           linestyle=linestyle[i], color=color[-1])
axins.set_yscale('log', base=10)
axins.set_yscale('log', base=10)
# axins.set_xticks([])  # 去掉x轴标签
# axins.set_yticks([])  # 去掉y轴标签

axins.set_xlabel('Degree')
axins.set_ylabel('Diameter')
# axins.set_title('Zoomed Out Overview ', fontsize='x-small')
axins.text(0.95, 0.95, 'Zoomed Out Overview', 
           transform=axins.transAxes, 
           fontsize=10, 
           ha='right', va='top',
           bbox=dict(facecolor='white', edgecolor='white', boxstyle='round,pad=0.2'))
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1746857/1724798508.py:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%